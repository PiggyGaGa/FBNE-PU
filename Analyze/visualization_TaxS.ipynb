# %%
import pandas as pd
import numpy as np
import time
import random
from sklearn.manifold import TSNE
from matplotlib import pyplot as plt
import matplotlib as mpl

# %%
NAME = '_TaxS_'
DIR = './Figure/'

# %%
name_basic = pd.read_pickle('~/TAX/TYC/ValidDATA/BasicFeature/TaxS_normalize.pickle')
name_label = pd.read_pickle('~/TAX/TYC/ValidDATA/Label/TaxS_clustering_label.pickle')

# %%
positive_label = name_label[name_label['label']==1]
negative_label = name_label[name_label['label']==0]
print('positive', positive_label.shape)
print('negative', negative_label.shape)
# Out:
# positive (64256, 1)
# negative (86533, 1)

# %%
positive_nsr = positive_label.index.values
negative_nsr = negative_label.index.values
positive_idx = np.random.choice(positive_nsr, 1000, replace=False)
negative_idx = np.random.choice(negative_nsr, 1000, replace=False)

# %%
# # data.fillna(method = 'ffill', axis = 0, inplace=True)
# data.isnull().sum().sum()

# %%
ts = time.time()

te = time.time()

# %%
label[label['label']==1]= '#00CED1'
label[label['label']==0]= '#DC143C'

# %%
data = pd.concat([name_basic.loc[positive_idx], name_basic.loc[negative_idx]], axis=0)
label = pd.concat([name_label.loc[positive_idx], name_label.loc[negative_idx]], axis=0)
print(data.shape)
print(label.shape)
x2_sample = TSNE(n_components=2).fit_transform(data.values)
fig, ax = plt.subplots(1, 1)
# ax.scatter(x2_sample[:, 0], x2_sample[:, 1], c=label.values, s=1, cmap=plt.get_cmap('tab20'))
ax.scatter(x2_sample[:, 0], x2_sample[:, 1], c=label.values.flatten(), s=10, cmap=plt.get_cmap('tab20'))
# ax.set_xlim(-100, 100)
# ax.set_ylim(-100, 100)
ax.set_aspect('equal')
plt.axis('off')
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, hspace = 0, wspace = 0)
plt.margins(0,0)
plt.savefig(DIR + NAME + 'Basic.pdf')
plt.show()

# %%
# PnCGCN
dp_gcn_feature = pd.read_pickle('all_PnCGCN_TaxS.pickle')
all_data = pd.concat([dp_gcn_feature.loc[positive_idx], dp_gcn_feature.loc[negative_idx]], axis=0)
all_label = pd.concat([name_label.loc[positive_idx], name_label.loc[negative_idx]], axis=0)
ts = time.time()
x2_sample = TSNE(n_components=2).fit_transform(all_data)
te = time.time()
print('total time {}'.format(te-ts))
all_label[all_label['label']==1]= '#00CED1'
all_label[all_label['label']==0]= '#DC143C'
fig, ax = plt.subplots(1, 1)
ax.scatter(x2_sample[:, 0], x2_sample[:, 1], c=all_label.values.flatten(), s=10, cmap=plt.get_cmap('tab20'))
ax.set_aspect('equal')
plt.axis('off')
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, hspace = 0, wspace = 0)
plt.margins(0,0)
plt.savefig(DIR + NAME + 'DP_GCN.pdf')
plt.show()
# Out:
# total time 14.1113920211792

# %%
# GCN
dp_gcn_feature = pd.read_pickle('../Result/TaxSGCN_embedding128.pickle')
all_data = pd.concat([dp_gcn_feature.loc[positive_idx], dp_gcn_feature.loc[negative_idx]], axis=0)
all_label = pd.concat([name_label.loc[positive_idx], name_label.loc[negative_idx]], axis=0)
ts = time.time()
x2_sample = TSNE(n_components=2).fit_transform(all_data)
te = time.time()
print('total time {}'.format(te-ts))
all_label[all_label['label']==1]= '#00CED1'
all_label[all_label['label']==0]= '#DC143C'
fig, ax = plt.subplots(1, 1)
ax.scatter(x2_sample[:, 0], x2_sample[:, 1], c=all_label.values.flatten(), s=10, cmap=plt.get_cmap('tab20'))
ax.set_aspect('equal')
plt.axis('off')
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, hspace = 0, wspace = 0)
plt.margins(0,0)
plt.savefig(DIR + NAME + 'GCN.pdf')
plt.show()
# Out:
# total time 15.312849998474121

# %%
# graph attention 

dp_gcn_feature = pd.read_pickle('all_graph_attention_TaxS.pickle')
all_data = pd.concat([dp_gcn_feature.loc[positive_idx], dp_gcn_feature.loc[negative_idx]], axis=0)
all_label = pd.concat([name_label.loc[positive_idx], name_label.loc[negative_idx]], axis=0)
ts = time.time()
x2_sample = TSNE(n_components=2).fit_transform(all_data)
te = time.time()
print('total time {}'.format(te-ts))
all_label[all_label['label']==1]= '#00CED1'
all_label[all_label['label']==0]= '#DC143C'
fig, ax = plt.subplots(1, 1)
ax.scatter(x2_sample[:, 0], x2_sample[:, 1], c=all_label.values.flatten(), s=10, cmap=plt.get_cmap('tab20'))
ax.set_aspect('equal')
plt.axis('off')
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, hspace = 0, wspace = 0)
plt.margins(0,0)
plt.savefig(DIR + NAME + 'graphAttention.pdf')
plt.show()
# Out:
# total time 15.835738182067871

# %%
# all_netra_Zhejiang.pickle
dp_gcn_feature = pd.read_pickle('all_netra_TaxS.pickle')
all_data = pd.concat([dp_gcn_feature.loc[positive_idx], dp_gcn_feature.loc[negative_idx]], axis=0)
all_label = pd.concat([name_label.loc[positive_idx], name_label.loc[negative_idx]], axis=0)
ts = time.time()
x2_sample = TSNE(n_components=2).fit_transform(all_data)
te = time.time()
print('total time {}'.format(te-ts))
all_label[all_label['label']==1]= '#00CED1'
all_label[all_label['label']==0]= '#DC143C'
fig, ax = plt.subplots(1, 1)
ax.scatter(x2_sample[:, 0], x2_sample[:, 1], c=all_label.values.flatten(), s=10, cmap=plt.get_cmap('tab20'))
ax.set_aspect('equal')
plt.axis('off')
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, hspace = 0, wspace = 0)
plt.margins(0,0)
plt.savefig(DIR + NAME + 'netra.pdf')
plt.show()
# Out:
# total time 14.280681610107422

# %%
# all_sdne_Zhejiang.pickle
dp_gcn_feature = pd.read_pickle('all_sdne_TaxS.pickle')
all_data = pd.concat([dp_gcn_feature.loc[positive_idx], dp_gcn_feature.loc[negative_idx]], axis=0)
all_label = pd.concat([name_label.loc[positive_idx], name_label.loc[negative_idx]], axis=0)
ts = time.time()
x2_sample = TSNE(n_components=2).fit_transform(all_data)
te = time.time()
print('total time {}'.format(te-ts))
all_label[all_label['label']==1]= '#00CED1'
all_label[all_label['label']==0]= '#DC143C'
fig, ax = plt.subplots(1, 1)
ax.scatter(x2_sample[:, 0], x2_sample[:, 1], c=all_label.values.flatten(), s=10, cmap=plt.get_cmap('tab20'))
ax.set_aspect('equal')
plt.axis('off')
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, hspace = 0, wspace = 0)
plt.margins(0,0)
plt.savefig(DIR + NAME + 'sdne.pdf')
plt.show()
# Out:
# total time 15.226348161697388

# %%
# all_sdne_Zhejiang.pickle
dp_gcn_feature = pd.read_pickle('all_GraRep_TaxS.pickle')
all_data = pd.concat([dp_gcn_feature.loc[positive_idx], dp_gcn_feature.loc[negative_idx]], axis=0)
all_label = pd.concat([name_label.loc[positive_idx], name_label.loc[negative_idx]], axis=0)
ts = time.time()
x2_sample = TSNE(n_components=2).fit_transform(all_data)
te = time.time()
print('total time {}'.format(te-ts))
all_label[all_label['label']==1]= '#00CED1'
all_label[all_label['label']==0]= '#DC143C'
fig, ax = plt.subplots(1, 1)
ax.scatter(x2_sample[:, 0], x2_sample[:, 1], c=all_label.values.flatten(), s=10, cmap=plt.get_cmap('tab20'))
ax.set_aspect('equal')
plt.axis('off')
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, hspace = 0, wspace = 0)
plt.margins(0,0)
plt.savefig(DIR + NAME + 'GraRep.pdf')
plt.show()

# %%
# all_walklets_TaxS.pickle
dp_gcn_feature = pd.read_pickle('all_walklets_TaxS.pickle')
all_data = pd.concat([dp_gcn_feature.loc[positive_idx], dp_gcn_feature.loc[negative_idx]], axis=0)
all_label = pd.concat([name_label.loc[positive_idx], name_label.loc[negative_idx]], axis=0)
ts = time.time()
x2_sample = TSNE(n_components=2).fit_transform(all_data)
te = time.time()
print('total time {}'.format(te-ts))
all_label[all_label['label']==1]= '#00CED1'
all_label[all_label['label']==0]= '#DC143C'
fig, ax = plt.subplots(1, 1)
ax.scatter(x2_sample[:, 0], x2_sample[:, 1], c=all_label.values.flatten(), s=10, cmap=plt.get_cmap('tab20'))
ax.set_aspect('equal')
plt.axis('off')
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, hspace = 0, wspace = 0)
plt.margins(0,0)
plt.savefig(DIR + NAME + 'walklets.pdf')
plt.show()
# Out:
# total time 19.268510341644287

# %%
# all_sdne_Zhejiang.pickle
dp_gcn_feature = pd.read_pickle('all_node2vec_TaxS.pickle')
all_data = pd.concat([dp_gcn_feature.loc[positive_idx], dp_gcn_feature.loc[negative_idx]], axis=0)
all_label = pd.concat([name_label.loc[positive_idx], name_label.loc[negative_idx]], axis=0)
ts = time.time()
x2_sample = TSNE(n_components=2).fit_transform(all_data)
te = time.time()
print('total time {}'.format(te-ts))
all_label[all_label['label']==1]= '#00CED1'
all_label[all_label['label']==0]= '#DC143C'
fig, ax = plt.subplots(1, 1)
ax.scatter(x2_sample[:, 0], x2_sample[:, 1], c=all_label.values.flatten(), s=10, cmap=plt.get_cmap('tab20'))
ax.set_aspect('equal')
plt.axis('off')
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, hspace = 0, wspace = 0)
plt.margins(0,0)
plt.savefig(DIR + NAME + 'node2vec.pdf')
plt.show()

# %%
# all_sdne_Zhejiang.pickle
dp_gcn_feature = pd.read_pickle('all_deepwalk_TaxS.pickle')
all_data = pd.concat([dp_gcn_feature.loc[positive_idx], dp_gcn_feature.loc[negative_idx]], axis=0)
all_label = pd.concat([name_label.loc[positive_idx], name_label.loc[negative_idx]], axis=0)
ts = time.time()
x2_sample = TSNE(n_components=2).fit_transform(all_data)
te = time.time()
print('total time {}'.format(te-ts))
all_label[all_label['label']==1]= '#00CED1'
all_label[all_label['label']==0]= '#DC143C'
fig, ax = plt.subplots(1, 1)
ax.scatter(x2_sample[:, 0], x2_sample[:, 1], c=all_label.values.flatten(), s=10, cmap=plt.get_cmap('tab20'))
ax.set_aspect('equal')
plt.axis('off')
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, hspace = 0, wspace = 0)
plt.margins(0,0)
plt.savefig(DIR + NAME + 'deepwalk.pdf')
plt.show()
